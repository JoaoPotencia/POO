// %% [markdown]
// # Atividade teste

// %% [markdown]
// Gere uma saída de texto entre aspas duplas, criando uma nova linha e posicionando o cursor na linha abaixo.Gere uma saída de texto entre aspas duplas, criando uma nova linha e posicionando o cursor na linha abaixo.

// %%
//Classe
String str = ("Atividade Teste\n");{// Criei uma String que recebia a variavel str e logo em seguida coloquei uma frase dei um println.
   
//Impressão de texto
System.out.println(str);//Dei um print com uma mensagem qualquer e a função é não criar uma nova linha abaixo da atual, deixando o cursor na mesma linha onde a string foi impressa.
    
}
// Out:
// Atividade Teste
// null
