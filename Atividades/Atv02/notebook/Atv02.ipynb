// %% [markdown]
// # Atv02

// %% [markdown]
// Exibir a mensagem “Informe um inteiro: “, deixando o cursor na mesma linha

// %%
System.out.print("Informe um inteiro: ");
// Out:
// Informe um inteiro:
// null

// %% [markdown]
// Atribuir o produto das variáveis b e c para a variável a

// %%
int b = 7;
int c = 4;
int a = 0;
    
a = (b * c);

System.out.println("A variável de a é: " + a);
// Out:
// A variável de a é: 28
// null

// %% [markdown]
// Demonstrar a execução do cálculo e utilizar um comentário para afirmar que é um programa de exemplo de folha de pagamento.

// %%
//declarando variáveis
int b = 7;
int c = 4;
int a = 0;

a = (b * c);//"a" recebe o produto de "b" vezes "c" e salva em a

System.out.println("-a- é: " + a);// Mensagem para o usuário + junta a mensagem com o valor da variável
// Out:
// -a- é: 28
// null
